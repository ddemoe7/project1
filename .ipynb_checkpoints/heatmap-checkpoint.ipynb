# %%
## Heatmap
### Number of sales by Zip, layering in demographic information

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gmaps
import json
import csv
import os

# Import API key
from api_keys import g_key

# %%
# Source data location
housingFile = 'source_data/housing_data_cleaned.csv'

# Read in source
housingDF = pd.read_csv(housingFile, low_memory=False)
housingDF.head()
# Out:
#   basements building_code_description category_code_description  census_tract  \
# 0         D         ROW 3 STY MASONRY             Single Family         241.0
# 1       NaN   RES CONDO 3 STY MAS+OTH             Single Family         337.0
# 2       NaN         ROW 2 STY MASONRY             Single Family         201.0
# 3         H   ROW B/GAR 2 STY MASONRY             Single Family         281.0
# 4       NaN         ROW 2 STY MASONRY             Single Family         293.0
#
#   central_air  depth  exempt_building  exempt_land  exterior_condition  \
# 0           N   67.0            49200            0                 4.0
# 1           Y    0.0            45000            0                 4.0
# 2         NaN   70.0                0            0                 4.0
# 3           N   95.5                0            0                 4.0
# 4         NaN  112.5                0            0                 4.0
#
#    fireplaces  ...  topography total_area  total_livable_area type_heater  \
# 0         0.0  ...           F     938.00              1344.0           A
# 1         0.0  ...         NaN       0.00               947.0         NaN
# 2         0.0  ...           F    1044.00              1190.0         NaN
# 3         0.0  ...           F    1686.53              1633.0           B
# 4         0.0  ...           F    2165.62              1320.0           B
#
#    unit  view_type year_built  year_built_estimate  zip_code  zoning
# 0   NaN          I       1895                    Y   19144.0    RSA5
# 1  B307          I       1970                    Y   19152.0     RM2
# 2   NaN          I       1940                    Y   19140.0     RM1
# 3   NaN          I       1940                    Y   19141.0    RSA3
# 4   NaN          I       1940                    Y   19124.0    RSA5
#
# [5 rows x 41 columns]

# %%
# Bring in demographics dataframe
demographicsFile = 'source_data/philly_demographics.csv'

# Read in demographics df
demographicsDF = pd.read_csv(demographicsFile)
demographicsDF.head()
# Out:
#            City    Zip                               NABE        Lat  \
# 0  Philadelphia  19102                        Center City  39.948498
# 1  Philadelphia  19103                   Center City West  39.953663
# 2  Philadelphia  19103                   Center City West  39.953860
# 3  Philadelphia  19104  University City, Mantua, Powelton  39.956417
# 4  Philadelphia  19106             Old City, Society Hill  39.949120
#
#        Long  MEDINC  P_WHITE  P_BLACK  P_HISP  P_ASIAN  P_OTHERS  \
# 0 -75.16683   90750     0.73     0.04    0.05     0.16      0.01
# 1 -75.17399   73611     0.72     0.06    0.06     0.12      0.04
# 2 -75.16713   73611     0.72     0.06    0.06     0.12      0.04
# 3 -75.20855   25865     0.35     0.42    0.05     0.14      0.04
# 4 -75.14397  109393     0.77     0.08    0.06     0.06      0.02
#
#    P_MinCOMBINED
# 0           0.27
# 1           0.28
# 2           0.28
# 3           0.65
# 4           0.23

# %%
# Make the name of the zip column the same
demographicsDF_update = demographicsDF.rename(columns={'Zip': 'zip_code'})
demographicsDF_update.head()
# Out:
#            City  zip_code                               NABE        Lat  \
# 0  Philadelphia     19102                        Center City  39.948498
# 1  Philadelphia     19103                   Center City West  39.953663
# 2  Philadelphia     19103                   Center City West  39.953860
# 3  Philadelphia     19104  University City, Mantua, Powelton  39.956417
# 4  Philadelphia     19106             Old City, Society Hill  39.949120
#
#        Long  MEDINC  P_WHITE  P_BLACK  P_HISP  P_ASIAN  P_OTHERS  \
# 0 -75.16683   90750     0.73     0.04    0.05     0.16      0.01
# 1 -75.17399   73611     0.72     0.06    0.06     0.12      0.04
# 2 -75.16713   73611     0.72     0.06    0.06     0.12      0.04
# 3 -75.20855   25865     0.35     0.42    0.05     0.14      0.04
# 4 -75.14397  109393     0.77     0.08    0.06     0.06      0.02
#
#    P_MinCOMBINED
# 0           0.27
# 1           0.28
# 2           0.28
# 3           0.65
# 4           0.23

# %%
# Merge dataframes on column (zip)
mergedDF = pd.merge(housingDF, demographicsDF_update, on='zip_code', how='inner')
mergedDF
# Out:
#        basements building_code_description category_code_description  \
# 0              D         ROW 3 STY MASONRY             Single Family
# 1              D         ROW 3 STY MASONRY             Single Family
# 2              C  SEMI/DET 2.5 STY MASONRY             Single Family
# 3              C  SEMI/DET 2.5 STY MASONRY             Single Family
# 4            NaN    SEMI/DET 2 STY MASONRY             Single Family
# ...          ...                       ...                       ...
# 130845       NaN   APTS 5-50 UNITS MASONRY              Multi Family
# 130846         0  RES CONDO 5+ STY MASONRY             Single Family
# 130847       NaN  RES CONDO 5+ STY MASONRY             Single Family
# 130848         0  RES CONDO 5+ STY MAS+OTH             Single Family
# 130849       NaN  RES CONDO 5+ STY MASONRY             Single Family
#
#         census_tract central_air   depth  exempt_building  exempt_land  \
# 0              241.0           N   67.00            49200            0
# 1              241.0           N   67.00            49200            0
# 2              252.0           N   96.74                0            0
# 3              252.0           N   96.74                0            0
# 4              242.0         NaN   85.70                0            0
# ...              ...         ...     ...              ...          ...
# 130845           8.0         NaN  161.50                0            0
# 130846           4.0           Y    0.00           568911            0
# 130847           4.0           Y    0.00           388995            0
# 130848           4.0           Y    0.00                0            0
# 130849           4.0           Y    0.00           383989            0
#
#         exterior_condition  fireplaces  ...         NABE        Lat  \
# 0                      4.0         0.0  ...   Germantown  40.033259
# 1                      4.0         0.0  ...   Germantown  40.030370
# 2                      7.0         0.0  ...   Germantown  40.033259
# 3                      7.0         0.0  ...   Germantown  40.030370
# 4                      4.0         0.0  ...   Germantown  40.033259
# ...                    ...         ...  ...          ...        ...
# 130845                 4.0         0.0  ...  Center City  39.948498
# 130846                 3.0         0.0  ...  Center City  39.948498
# 130847                 3.0         0.0  ...  Center City  39.948498
# 130848                 1.0         0.0  ...  Center City  39.948498
# 130849                 3.0         0.0  ...  Center City  39.948498
#
#              Long MEDINC  P_WHITE  P_BLACK P_HISP  P_ASIAN  P_OTHERS  \
# 0      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# 1      -75.165700  33786     0.16     0.75   0.04     0.02      0.03
# 2      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# 3      -75.165700  33786     0.16     0.75   0.04     0.02      0.03
# 4      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# ...           ...    ...      ...      ...    ...      ...       ...
# 130845 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130846 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130847 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130848 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130849 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
#
#         P_MinCOMBINED
# 0                0.84
# 1                0.84
# 2                0.84
# 3                0.84
# 4                0.84
# ...               ...
# 130845           0.27
# 130846           0.27
# 130847           0.27
# 130848           0.27
# 130849           0.27
#
# [130850 rows x 52 columns]

# %%
# Dropping empty rows
#mergedDF = mergedDF.dropna()

# NOT WORKING RN

# %%
# Sort df by number of sales
#mergedDF.sort_values(by=['sale_price'])
mergedDF.sort_values(by=['sale_price', 'zip_code'])

# Reindex dataframe
mergedDF.reset_index(drop=True)
# Out:
#        basements building_code_description category_code_description  \
# 0              D         ROW 3 STY MASONRY             Single Family
# 1              D         ROW 3 STY MASONRY             Single Family
# 2              C  SEMI/DET 2.5 STY MASONRY             Single Family
# 3              C  SEMI/DET 2.5 STY MASONRY             Single Family
# 4            NaN    SEMI/DET 2 STY MASONRY             Single Family
# ...          ...                       ...                       ...
# 130845       NaN   APTS 5-50 UNITS MASONRY              Multi Family
# 130846         0  RES CONDO 5+ STY MASONRY             Single Family
# 130847       NaN  RES CONDO 5+ STY MASONRY             Single Family
# 130848         0  RES CONDO 5+ STY MAS+OTH             Single Family
# 130849       NaN  RES CONDO 5+ STY MASONRY             Single Family
#
#         census_tract central_air   depth  exempt_building  exempt_land  \
# 0              241.0           N   67.00            49200            0
# 1              241.0           N   67.00            49200            0
# 2              252.0           N   96.74                0            0
# 3              252.0           N   96.74                0            0
# 4              242.0         NaN   85.70                0            0
# ...              ...         ...     ...              ...          ...
# 130845           8.0         NaN  161.50                0            0
# 130846           4.0           Y    0.00           568911            0
# 130847           4.0           Y    0.00           388995            0
# 130848           4.0           Y    0.00                0            0
# 130849           4.0           Y    0.00           383989            0
#
#         exterior_condition  fireplaces  ...         NABE        Lat  \
# 0                      4.0         0.0  ...   Germantown  40.033259
# 1                      4.0         0.0  ...   Germantown  40.030370
# 2                      7.0         0.0  ...   Germantown  40.033259
# 3                      7.0         0.0  ...   Germantown  40.030370
# 4                      4.0         0.0  ...   Germantown  40.033259
# ...                    ...         ...  ...          ...        ...
# 130845                 4.0         0.0  ...  Center City  39.948498
# 130846                 3.0         0.0  ...  Center City  39.948498
# 130847                 3.0         0.0  ...  Center City  39.948498
# 130848                 1.0         0.0  ...  Center City  39.948498
# 130849                 3.0         0.0  ...  Center City  39.948498
#
#              Long MEDINC  P_WHITE  P_BLACK P_HISP  P_ASIAN  P_OTHERS  \
# 0      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# 1      -75.165700  33786     0.16     0.75   0.04     0.02      0.03
# 2      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# 3      -75.165700  33786     0.16     0.75   0.04     0.02      0.03
# 4      -75.177865  33786     0.16     0.75   0.04     0.02      0.03
# ...           ...    ...      ...      ...    ...      ...       ...
# 130845 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130846 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130847 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130848 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
# 130849 -75.166830  90750     0.73     0.04   0.05     0.16      0.01
#
#         P_MinCOMBINED
# 0                0.84
# 1                0.84
# 2                0.84
# 3                0.84
# 4                0.84
# ...               ...
# 130845           0.27
# 130846           0.27
# 130847           0.27
# 130848           0.27
# 130849           0.27
#
# [130850 rows x 52 columns]

# %%
## Creating Heat Map

# Need to convert percentages
print(mergedDF.dtypes)
#print(mergedDF.sale_price)
#print(mergedDF.MEDINC)
# Out:
# basements                     object
# building_code_description     object
# category_code_description     object
# census_tract                 float64
# central_air                   object
# depth                        float64
# exempt_building                int64
# exempt_land                    int64
# exterior_condition           float64
# fireplaces                   float64
# frontage                     float64
# fuel                          object
# garage_spaces                float64
# garage_type                   object
# geographic_ward              float64
# interior_condition           float64
# location                      object
# market_value                   int64
# market_value_date            float64
# number_of_bathrooms          float64
# number_of_bedrooms           float64
# number_of_rooms              float64
# number_stories               float64
# quality_grade                float64
# sale_date                      int64
# sale_price                     int64
# street_designation            object
# street_direction              object
# street_name                   object
# taxable_building               int64
# taxable_land                   int64
# topography                    object
# total_area                   float64
# total_livable_area           float64
# type_heater                   object
# unit                          object
# view_type                     object
# year_built                    object
# year_built_estimate           object
# zip_code                     float64
# zoning                        object
# City                          object
# NABE                          object
# Lat                          float64
# Long                         float64
# MEDINC                         int64
# P_WHITE                      float64
# P_BLACK                      float64
# P_HISP                       float64
# P_ASIAN                      float64
# P_OTHERS                     float64
# P_MinCOMBINED                float64
# dtype: object

# %%
# Configure gmaps with API key
gmaps.configure(api_key = g_key)

# Store lat and long into locations
locations = mergedDF[["Lat", "Long"]]
#locations = mergedDF[["zip_code"]]
#pctWhite = mergedDF["P_WHITE"].astype(float)
byZIP = mergedDF["zip_code"].astype(float)
numberSales = mergedDF["sale_price"]
area = mergedDF["total_livable_area"].astype(float)

# %%
# Plot heatmap
fig = gmaps.figure()

# Create and add heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = area, dissipating = False, max_intensity = 50, point_radius = 1.5)

fig.add_layer(heat_layer)

# Display
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# With more parameters

heatmapDF = mergedDF[(mergedDF['sale_price'] >= 120000) & (mergedDF['sale_price'] <= 900000)]
heatmapDF = heatmapDF[heatmapDF['MEDINC'] >= 35000]
heatmapDF = heatmapDF[heatmapDF['P_BLACK'] >= .40]
heatmapDF.head()
# Out:
#       basements building_code_description category_code_description  \
# 30480       NaN         ROW 3 STY MASONRY             Single Family
# 30481       NaN         ROW 3 STY MASONRY             Single Family
# 30482       NaN         ROW 3 STY MASONRY             Single Family
# 30483       NaN         ROW 3 STY MASONRY             Single Family
# 30484         A         ROW 2 STY MASONRY             Single Family
#
#        census_tract central_air  depth  exempt_building  exempt_land  \
# 30480          30.0         NaN   44.0           305046            0
# 30481          30.0         NaN   44.0           305046            0
# 30482          30.0         NaN   44.0           305046            0
# 30483          30.0         NaN   44.0           305046            0
# 30484          13.0           Y   41.0                0            0
#
#        exterior_condition  fireplaces  ...  \
# 30480                 0.0         0.0  ...
# 30481                 0.0         0.0  ...
# 30482                 0.0         0.0  ...
# 30483                 0.0         0.0  ...
# 30484                 3.0         0.0  ...
#
#                                                    NABE        Lat       Long  \
# 30480  Southwest Center City, Point Breeze, Grays Ferry  39.939560 -75.180510
# 30481  Southwest Center City, Point Breeze, Grays Ferry  39.945590 -75.181060
# 30482  Southwest Center City, Point Breeze, Grays Ferry  39.937726 -75.167021
# 30483  Southwest Center City, Point Breeze, Grays Ferry  39.933903 -75.180115
# 30484  Southwest Center City, Point Breeze, Grays Ferry  39.939560 -75.180510
#
#       MEDINC  P_WHITE  P_BLACK P_HISP  P_ASIAN  P_OTHERS  P_MinCOMBINED
# 30480  63524     0.45     0.43   0.05     0.04      0.04           0.55
# 30481  63524     0.45     0.43   0.05     0.04      0.04           0.55
# 30482  63524     0.45     0.43   0.05     0.04      0.04           0.55
# 30483  63524     0.45     0.43   0.05     0.04      0.04           0.55
# 30484  63524     0.45     0.43   0.05     0.04      0.04           0.55
#
# [5 rows x 52 columns]

# %%
heatmapDF.dropna()
heatmapDF
# Out:
#        basements  building_code_description category_code_description  \
# 30480        NaN          ROW 3 STY MASONRY             Single Family
# 30481        NaN          ROW 3 STY MASONRY             Single Family
# 30482        NaN          ROW 3 STY MASONRY             Single Family
# 30483        NaN          ROW 3 STY MASONRY             Single Family
# 30484          A          ROW 2 STY MASONRY             Single Family
# ...          ...                        ...                       ...
# 117693       NaN    ROW B/GAR 2 STY MASONRY             Single Family
# 117697         F    ROW B/GAR 2 STY MASONRY             Single Family
# 117699       NaN  S/D CONV APT 3 STY MAS+OT              Multi Family
# 117700       NaN  DET W/D GAR 3 STY MASONRY             Single Family
# 117706       NaN    DET 3 STY MASONRY+OTHER             Single Family
#
#         census_tract central_air   depth  exempt_building  exempt_land  \
# 30480           30.0         NaN   44.00           305046            0
# 30481           30.0         NaN   44.00           305046            0
# 30482           30.0         NaN   44.00           305046            0
# 30483           30.0         NaN   44.00           305046            0
# 30484           13.0           Y   41.00                0            0
# ...              ...         ...     ...              ...          ...
# 117693          98.0           Y  108.79                0            0
# 117697          98.0         NaN   92.50            45000            0
# 117699         114.0         NaN  140.36                0            0
# 117700         375.0         NaN  150.00            45000            0
# 117706         375.0         NaN  150.00            45000            0
#
#         exterior_condition  fireplaces  ...  \
# 30480                  0.0         0.0  ...
# 30481                  0.0         0.0  ...
# 30482                  0.0         0.0  ...
# 30483                  0.0         0.0  ...
# 30484                  3.0         0.0  ...
# ...                    ...         ...  ...
# 117693                 4.0         0.0  ...
# 117697                 4.0         0.0  ...
# 117699                 4.0         0.0  ...
# 117700                 4.0         0.0  ...
# 117706                 4.0         0.0  ...
#
#                                                     NABE        Lat  \
# 30480   Southwest Center City, Point Breeze, Grays Ferry  39.939560
# 30481   Southwest Center City, Point Breeze, Grays Ferry  39.945590
# 30482   Southwest Center City, Point Breeze, Grays Ferry  39.937726
# 30483   Southwest Center City, Point Breeze, Grays Ferry  39.933903
# 30484   Southwest Center City, Point Breeze, Grays Ferry  39.939560
# ...                                                  ...        ...
# 117693                                         Overbrook  39.977297
# 117697                                         Overbrook  39.977297
# 117699                                         Overbrook  39.977297
# 117700                                         Overbrook  39.977297
# 117706                                         Overbrook  39.977297
#
#              Long MEDINC  P_WHITE  P_BLACK P_HISP  P_ASIAN  P_OTHERS  \
# 30480  -75.180510  63524     0.45     0.43   0.05     0.04      0.04
# 30481  -75.181060  63524     0.45     0.43   0.05     0.04      0.04
# 30482  -75.167021  63524     0.45     0.43   0.05     0.04      0.04
# 30483  -75.180115  63524     0.45     0.43   0.05     0.04      0.04
# 30484  -75.180510  63524     0.45     0.43   0.05     0.04      0.04
# ...           ...    ...      ...      ...    ...      ...       ...
# 117693 -75.273268  48369     0.06     0.87   0.04     0.01      0.02
# 117697 -75.273268  48369     0.06     0.87   0.04     0.01      0.02
# 117699 -75.273268  48369     0.06     0.87   0.04     0.01      0.02
# 117700 -75.273268  48369     0.06     0.87   0.04     0.01      0.02
# 117706 -75.273268  48369     0.06     0.87   0.04     0.01      0.02
#
#         P_MinCOMBINED
# 30480            0.55
# 30481            0.55
# 30482            0.55
# 30483            0.55
# 30484            0.55
# ...               ...
# 117693           0.94
# 117697           0.94
# 117699           0.94
# 117700           0.94
# 117706           0.94
#
# [20304 rows x 52 columns]

# %%
# Adding markers to the map
info_box = """
<d1>
<dt>Neighborhood:</dt><dd>{NABE}</dd>
<dt>Zip code:</dt><dd>{zip_code}</dd>
<dt>Sale price:</dt><dd>{sale_price}</dd>
<dt>Median income:</dt><dd>{MEDINC}</dd>
"""

#Storing the df row
house_info = [info_box.format(**row) for index, row in heatmapDF.iterrows()]

locations = heatmapDF[["Lat", "Long"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
